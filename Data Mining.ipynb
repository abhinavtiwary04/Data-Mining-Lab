# %%
import pandas as pd

# %%
df=pd.read_csv("C:\english-premier-league-players-dataset\epldata_final.csv")
df
# Out:
#                     name      club  age position  position_cat  market_value  \
# 0         Alexis Sanchez   Arsenal   28       LW             1          65.0
# 1             Mesut Ozil   Arsenal   28       AM             1          50.0
# 2              Petr Cech   Arsenal   35       GK             4           7.0
# 3           Theo Walcott   Arsenal   28       RW             1          20.0
# 4      Laurent Koscielny   Arsenal   31       CB             3          22.0
# ..                   ...       ...  ...      ...           ...           ...
# 456  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 457       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 458            Sam Byram  West+Ham   23       RB             3           4.5
# 459      Ashley Fletcher  West+Ham   21       CF             1           1.0
# 460         Diafra Sakho  West+Ham   27       CF             1          10.0
#
# ...

# %%
df.aggregate({'age':['sum','max','min'],'fpl_points':['sum','max','min']})
# Out:
#        age  fpl_points
# sum  12357       26422
# max     38         264
# min     17           0

# %%
df.sample(100)
# Out:
#                 name               club  age position  position_cat  \
# 458        Sam Byram           West+Ham   23       RB             3
# 61    Markus Suttner  Brighton+and+Hove   30       LB             3
# 396  Ã‰tienne Capoue            Watford   29       DM             2
# 137   Kevin Mirallas            Everton   29       RW             1
# 211      Molla Wague     Leicester+City   26       CB             3
# ..               ...                ...  ...      ...           ...
# 141      Joel Robles            Everton   27       GK             4
# 148    Mason Holgate            Everton   20       CB             3
# 314     Steven Davis        Southampton   32       CM             2
# 24    Carl Jenkinson            Arsenal   25       RB             3
# 313     Maya Yoshida        Southampton   28       CB             3
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 458           4.5         198        4.5   0.30%          29     1.0
# ...

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
plt.rcParams['axes.labelsize']=14
plt.rcParams['xtick.labelsize']=12
plt.rcParams['ytick.labelsize']=12

# %%
import seaborn as sns
color=sns.color_palette()
sns.set_style('darkgrid')
import sklearn
from sklearn.model_selection import train_test_split

# %%
correlation_matrix=df.corr()
plt.subplots(figsize=(8,6))
sns.heatmap(correlation_matrix,center=0,annot=True,linewidths=.3)

# %%
corr=df.corr()

# %%
corr['age'].sort_values(ascending=False)
# Out:
# age             1.000000
# age_cat         0.972199
# position_cat    0.220678
# fpl_points      0.187785
# region          0.086430
# club_id        -0.002868
# page_views     -0.048682
# new_signing    -0.079190
# fpl_value      -0.097659
# big_club       -0.123566
# new_foreign    -0.125400
# market_value   -0.132396
# Name: age, dtype: float64
